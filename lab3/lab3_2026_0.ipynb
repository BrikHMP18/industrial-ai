# %%
import pandas as pd

# %%
data = pd.read_csv('data_ejemplo/sensor.csv')

# %%
data.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
data.shape
# Out:
# (220321, 55)

# %%
data.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
data.tail()
# Out:
#         Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 220316      220316  2018-08-31 23:56:00   2.400463   47.69965  50.564240
# 220317      220317  2018-08-31 23:57:00   2.396528   47.69965  50.520830
# 220318      220318  2018-08-31 23:58:00   2.406366   47.69965  50.520832
# 220319      220319  2018-08-31 23:59:00   2.396528   47.69965  50.520832
# 220320           3                    3   1.000000    1.00000   0.000000
#
#         sensor_03   sensor_04  sensor_05  sensor_06  sensor_07  ...  \
# 220316  43.142361  630.902771   65.83363   15.15480   16.70284  ...
# 220317  43.142361  625.925903   67.29445   15.08970   16.70284  ...
# 220318  43.142361  635.648100   65.09175   15.11863   16.56539  ...
# 220319  43.142361  639.814800   65.45634   15.11863   16.65220  ...
# 220320   0.000000    0.000000    1.00000    0.00000    1.00000  ...
#
#         sensor_43  sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  \
# ...

# %% [markdown]
# ## EDA

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 220321 entries, 0 to 220320
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              220321 non-null  int64
#  1   timestamp               220321 non-null  str
#  2   sensor_00               210113 non-null  float64
#  3   sensor_01               219952 non-null  float64
#  4   sensor_02               220302 non-null  float64
#  5   sensor_03               220302 non-null  float64
#  6   sensor_04               220302 non-null  float64
#  7   sensor_05               220302 non-null  float64
#  8   sensor_06               215523 non-null  float64
#  9   sensor_07               214870 non-null  float64
#  10  sensor_08               215214 non-null  float64
#  11  sensor_09               215726 non-null  float64
#  12  sensor_10               220302 non-null  float64
#  13  sensor_11               220302 non-null  float64
# ...

# %% [markdown]
# #### Eliminacion de ruido

# %%
cleaned_data = data.copy()

# %%
cleaned_data = cleaned_data.iloc[:-1]

# %%
cleaned_data.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %% [markdown]
# #### Formato correcto del timestamp

# %%
cleaned_data['timestamp'] = pd.to_datetime(cleaned_data['timestamp'])

# %%
cleaned_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 220320 entries, 0 to 220319
# Data columns (total 55 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              220320 non-null  int64
#  1   timestamp               220320 non-null  datetime64[us]
#  2   sensor_00               210112 non-null  float64
#  3   sensor_01               219951 non-null  float64
#  4   sensor_02               220301 non-null  float64
#  5   sensor_03               220301 non-null  float64
#  6   sensor_04               220301 non-null  float64
#  7   sensor_05               220301 non-null  float64
#  8   sensor_06               215522 non-null  float64
#  9   sensor_07               214869 non-null  float64
#  10  sensor_08               215213 non-null  float64
#  11  sensor_09               215725 non-null  float64
#  12  sensor_10               220301 non-null  float64
# ...

# %%
cleaned_data.head()
# Out:
#    Unnamed: 0           timestamp  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0           0 2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760
# 1           1 2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760
# 2           2 2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570
# 3           3 2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568
# 4           4 2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568
#
#    sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  sensor_44  \
# 0   634.3750   76.45975   13.41146   16.13136  ...   41.92708  39.641200
# 1   634.3750   76.45975   13.41146   16.13136  ...   41.92708  39.641200
# 2   638.8889   73.54598   13.32465   16.03733  ...   41.66666  39.351852
# 3   628.1250   76.98898   13.31742   16.24711  ...   40.88541  39.062500
# 4   636.4583   76.58897   13.35359   16.21094  ...   41.40625  38.773150
#
# ...

# %%
cleaned_data = cleaned_data.sort_values(by='timestamp')

# %%
cleaned_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 cleaned_data.head()
#
# NameError: name 'cleaned_data' is not defined

# %% [markdown]
# #### Renombrado

# %%
cleadned_data = cleadned_data.rename(columns={'machine_status;;;;;;;;': 'machine_status'})

# %%
cleaned_data.head()
# Out:
#    Unnamed: 0           timestamp  sensor_00  sensor_01  sensor_02  sensor_03  \
# 0           0 2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760
# 1           1 2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760
# 2           2 2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570
# 3           3 2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568
# 4           4 2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568
#
#    sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  sensor_44  \
# 0   634.3750   76.45975   13.41146   16.13136  ...   41.92708  39.641200
# 1   634.3750   76.45975   13.41146   16.13136  ...   41.92708  39.641200
# 2   638.8889   73.54598   13.32465   16.03733  ...   41.66666  39.351852
# 3   628.1250   76.98898   13.31742   16.24711  ...   40.88541  39.062500
# 4   636.4583   76.58897   13.35359   16.21094  ...   41.40625  38.773150
#
# ...

# %%
print(cleadned_data['machine_status'].unique())
# Out:
# <StringArray>
# ['NORMAL;;;;;;;;', 'BROKEN;;;;;;;;', 'RECOVERING;;;;;;;;']
# Length: 3, dtype: str

# %%
# Clean up the values in 'machine_status' column to remove trailing semicolons
cleaned_data['machine_status'] = cleaned_data['machine_status'].str.replace(';', '', regex=False)
